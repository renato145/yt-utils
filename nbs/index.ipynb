# %%
#| hide
from yt_utils.core import *

# %% [markdown]
# # yt-utils
#
# > Youtube utilities

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install yt_utils in Development mode

# %% [markdown]
# ```sh
# # make sure yt_utils package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to yt_utils
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/renato145/yt-utils.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c renato145 yt_utils
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install yt_utils
# ```
#
#
# [repo]: https://github.com/renato145/yt-utils
# [docs]: https://renato145.github.io/yt-utils/
# [pypi]: https://pypi.org/project/yt-utils/
# [conda]: https://anaconda.org/renato145/yt-utils

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/renato145/yt-utils
# [docs]: https://renato145.github.io/yt-utils/
# [pypi]: https://pypi.org/project/yt-utils/
# [conda]: https://anaconda.org/renato145/yt-utils

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
